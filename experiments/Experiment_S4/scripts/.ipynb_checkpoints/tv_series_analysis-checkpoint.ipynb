# %%
from __future__ import print_function
import psycopg2 as pg2
import numpy as np
import re
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sb
import pandas as pd
import gensim
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from scipy.spatial.distance import jaccard as jaccard_distance
from scipy.spatial.distance import cosine as cosine_distance
from scipy.spatial.distance import hamming as hamming_distance
from scipy import stats as ss
from sklearn.cross_decomposition import CCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as FLD
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import resample
from sklearn.model_selection import StratifiedKFold
from sklearn.svm import LinearSVC
import csv
import sys
np.set_printoptions(threshold=sys.maxsize)
import os.path
import itertools
import random
import json
from copy import copy
import plotly
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from IPython.display import clear_output
import textstat as ts
from numpy.polynomial.polynomial import polyfit

from matplotlib import rc
font = {'family' : 'normal',
        'size'   : 16}
rc('text', usetex=False)
rc('font', **font)

# %%
# create descriptive labels for each (phase, trial)
data_type = {'academicCaptionA':np.float_,
'academicCaptionB':np.float_,
'actA':np.float_,
'actB':np.float_,
'activityCategoriesA':np.object_,
'activityCategoriesB':np.object_,
'activitySimilarityAB':np.float_,
'activityTextA':str,
'activityTextB':str,
'age':str,
'analyticalCaptionA':np.float_,
'analyticalCaptionB':np.float_,
'attentionA':np.float_,
'attentionB':np.float_,
'awareA':np.float_,
'awareB':np.float_,
'catch1':np.float_,
'catch10':np.float_,
'catch11':np.float_,
'catch12':np.float_,
'catch13':str,
'catch14':np.float_,
'catch15':np.float_,
'catch16':np.float_,
'catch17':np.float_,
'catch2':np.float_,
'catch3':np.float_,
'catch4':np.float_,
'catch5':np.float_,
'catch6':np.float_,
'catch7':np.float_,
'catch8':np.float_,
'catch9':np.float_,
'causalAB':np.float_,
'centerA':np.float_,
'centerB':np.float_,
'certainA':np.float_,
'certainB':np.float_,
'cherishedCaptionA':np.float_,
'cherishedCaptionB':np.float_,
'childishCaptionA':np.float_,
'childishCaptionB':np.float_,
'closeA':np.float_,
'closeB':np.float_,
'consequenceA':np.float_,
'consequenceB':np.float_,
'consistentA':np.float_,
'consistentB':np.float_,
'controlA':np.float_,
'controlB':np.float_,
'copeA':np.float_,
'copeB':np.float_,
'currentEmotionA':np.float_,
'currentEmotionB':np.float_,
'despicableCaptionA':np.float_,
'despicableCaptionB':np.float_,
'effectiveCaptionA':np.float_,
'effectiveCaptionB':np.float_,
'emotionA':np.object_,
'emotionB':np.object_,
'emotionalSimilarityAB':np.float_,
'english':np.float_,
'episodic1':np.float_,
'episodic2':np.float_,
'episodic3':np.float_,
'ethnicity':str,
'expectedA':np.float_,
'expectedB':np.float_,
'familiarA':np.float_,
'familiarB':np.float_,
'familyA':np.float_,
'familyB':np.float_,
'fatiguingCaptionA':np.float_,
'fatiguingCaptionB':np.float_,
'feedback':str,
'frustratingCaptionA':np.float_,
'frustratingCaptionB':np.float_,
'future1':np.float_,
'future2':np.float_,
'gender':str,
'goofyCaptionA':np.float_,
'goofyCaptionB':np.float_,
'grotesqueCaptionA':np.float_,
'grotesqueCaptionB':np.float_,
'heartwarmingCaptionA':np.float_,
'heartwarmingCaptionB':np.float_,
'helpfulCaptionA':np.float_,
'helpfulCaptionB':np.float_,
'indoorA':np.float_,
'indoorB':np.float_,
'initiatedA':np.float_,
'initiatedB':np.float_,
'instructionalCaptionA':np.float_,
'instructionalCaptionB':np.float_,
'interactA':np.float_,
'interactB':np.float_,
'language':np.object_,
'locationA':np.float_,
'locationB':np.float_,
'maliciousCaptionA':np.float_,
'maliciousCaptionB':np.float_,
'memoryA':str,
'memoryB':str,
'mischievousCaptionA':np.float_,
'mischievousCaptionB':np.float_,
'moreRecentAB':np.float_,
'overallSimilarityAB':np.float_,
'peopleSimilarityAB':np.float_,             
'preciousCaptionA':np.float_,
'preciousCaptionB':np.float_,
'pressureA':np.float_,
'pressureB':np.float_,
'productiveCaptionA':np.float_,
'productiveCaptionB':np.float_,
'promptA2':str,
'promptB2':str,
'properA':np.float_,
'properB':np.float_,
'race':np.object_,
'recallFreqA':np.float_,
'recallFreqB':np.float_,
'regularCaptionA':np.float_,
'regularCaptionB':np.float_,
'relateAB':str,
'relationshipA':np.float_,
'relationshipB':np.float_,
'reoccurA':np.float_,
'reoccurB':np.float_,
'repulsiveCaptionA':np.float_,
'repulsiveCaptionB':np.float_,
'riskA':np.float_,
'riskB':np.float_,
'scholarlyCaptionA':np.float_,
'scholarlyCaptionB':np.float_,
'self-esteemA':np.float_,
'self-esteemB':np.float_,
'semantic1':np.float_,
'semantic2':np.float_,
'sentimentalCaptionA':np.float_,
'sentimentalCaptionB':np.float_,
'settingA':np.float_,
'settingB':np.float_,
'sharedPeopleAB':np.float_,
'similarEnvironmentA':np.float_,
'similarEnvironmentB':np.float_,
'spatial1':np.float_,
'spatial2':np.float_,
'spatial3':np.float_,
'spatialDistanceAB':np.object_,
'spatialScaleA':np.float_,
'spatialScaleB':np.float_,
'spatialSimilarityAB':np.float_,
'stakeA':np.float_,
'stakeB':np.float_,
'standardCaptionA':np.float_,
'standardCaptionB':np.float_,
'stressfulCaptionA':np.float_,
'stressfulCaptionB':np.float_,
'temporalDistanceAB':np.object_,
'temporalScaleA':np.float_,
'temporalScaleB':np.float_,
'temporalSeparationAB':np.float_,
'tiresomeCaptionA':np.float_,
'tiresomeCaptionB':np.float_,
'transportability1':np.float_,
'transportability2':np.float_,
'transportability3':np.float_,
'transportability4':np.float_,
'transportability5':np.float_,
'transportability6':np.float_,
'transportability7':np.float_,
'transportability8':np.float_,
'transportability9':np.float_,
'transportability10':np.float_,
'transportability11':np.float_,
'transportability12':np.float_,
'transportability13':np.float_,
'transportability14':np.float_,
'transportability15':np.float_,
'transportability16':np.float_,
'transportability17':np.float_,
'transportability18':np.float_,
'transportability19':np.float_,
'turkExperience':np.float_,             
'typicalCaptionA':np.float_,
'typicalCaptionB':np.float_,
'understandingA':np.float_,
'understandingB':np.float_,
'usefulCaptionA':np.float_,
'usefulCaptionB':np.float_,
'usualCaptionA':np.float_,
'usualCaptionB':np.float_,
'vividnessA':np.float_,
'vividnessB':np.float_,
'wackyCaptionA':np.float_,
'wackyCaptionB':np.float_,
'wordCloudA':np.object_,
'wordCloudB':np.object_,
'workerID':str}


tempSepDict = {0:'< 24 hrs',
               1:'< 7 days',
               2:'< 30 days',
               3:'< 12 months',
               4:'< 5 years',
               5:'5+ years'
              }

# %%
def makeScatter(df, xcol, ycol, jitter, lineFit):
    fig, ax = plt.subplots(1,1)
    fig.set_size_inches(5, 5)

    plot_df = df[[xcol, ycol]]

    x = plot_df[xcol]
    y = plot_df[ycol]
    rho = ss.spearmanr(x, y)[0]

    if jitter:
        x = x + np.random.normal(0, 0.1, plot_df.shape[0])
        y = y + np.random.normal(0, 0.1, plot_df.shape[0])


    plot_df.plot.scatter(x=xcol,
                         y=ycol,
                         s=20,
                         ax=ax
                        )

    if lineFit:
        # Fit with polyfit
        b, m = polyfit(x, y, 1)

        ax.plot(x, y, '.')
        ax.plot(x, b + m * x, '-')

        minx, maxx = ax.get_xlim()
        rangex = maxx - minx
        miny, maxy = ax.get_ylim()
        rangey = maxy - miny
        ax.text((minx + maxx)/2, maxy - 0.02*rangey, 'rho = ' + str(rho), ha='center', va='top')
            
def jaccard_similarity(list1, list2):
    intersection = len(list(set(list1).intersection(list2)))
    union = (len(list1) + len(list2)) - intersection
    return float(intersection) / union

def makeJaccard(df, colA, colB):
    return df[[colA, colB]].apply(lambda rw: jaccard_similarity(rw[0], rw[1]), axis=1)

# %%
table_name = 'main'
select_columns = 'workerid, hitid, datastring'
# select_columns = 'workerid, assignmentid, hitid, status, datastring'
pattern_filter = "status IN (5) AND hitid IN ('3XBXDSS888VDA11Z0P4JEESTADHLXC', '3NQUW096N6KN95J1X9Y5YB6B3AW9LN', '3U74KRR67MXWHKV07SJ123BC37ETNF', '3DWNFENNE37GH9PPDTQ11OI3EQDJ4U', '36QZ6V1589P8XA2UFTQX6T7K9NHUSD', '3OYHVNTV5TAFWM5PEY5MG1OLA9VKOS', '37ZQELHEQ0AS4P5GYVIPGPGK95INMK', '3MVY4USGB6Z3OJ7ULC1JNQJ9FWSSI9', '38F60IALAGTTWO3T6MH3RRFZVNF0T5')" # grab all entries that successfully completed the HIT

# %%
conn = pg2.connect(user='wuorsurrbxjlgo',
                   password='11b722ee64c73480b7bc2ae64cec8a218dc44f708e16114bc6219e282d505d1a',
                   host='ec2-52-1-20-236.compute-1.amazonaws.com',
                   port='5432',
                   database='ddjst7vhtqfvmf'
                  )
cur = conn.cursor()
cur.execute('SELECT {coi} FROM {tn} WHERE {pf}'.format(coi=select_columns, tn=table_name, pf=pattern_filter))
all_rows = cur.fetchall()
conn.close()

# %%
# Initialize empty data frame
num_entries = len(all_rows)
index = np.arange(num_entries)
columns = list(data_type.keys())
df = pd.DataFrame(index=index, columns=columns)
df = df.astype(data_type)

# %%
# get all question names and initialize empty pandas dataframe
for rwid, rw in enumerate(all_rows):
    jsdict = json.loads(rw[2])
    df.at[rwid, 'workerID'] = jsdict['workerId']
    df.at[rwid, 'hitID'] = jsdict['hitId']
    df.at[rwid, 'assignmentID'] = jsdict['assignmentId']
    df.at[rwid, 'condition'] = jsdict['condition']
    for i, dataEntry in enumerate(jsdict['data']):
        if 'trialdata' in dataEntry.keys():
            if 'response' in dataEntry['trialdata']:
                question = dataEntry['trialdata']['question']
                response = dataEntry['trialdata']['response']
                if (question in df.columns):
                    df.at[rwid, question] = response
            elif 'memoryA' in dataEntry['trialdata']:
                df.at[rwid, 'memoryA'] = dataEntry['trialdata']['memoryA']
                df.at[rwid, 'memoryB'] = dataEntry['trialdata']['memoryB']

# %%
if np.isin('catch13' , df.columns):
    df['catch13'] = [response.lower() if response != 'nan' else 'nan' for response in df['catch13']]
# aggregate 'yesterday' times
df = df.set_index('workerID')

# %%
# catch trial summary

# create dictionary of correct answers
catch_answer_key = {'catch1':0,
                    'catch2':0,
                    'catch3':3,
                    'catch4':10,
                    'catch5':0,
                    'catch6':3,
                    'catch7':1,
                    'catch8':2,
                    'catch9':3,
                    'catch10':2,
                    'catch11':0,
                    'catch12':1,
                    'catch13':'in',
                    'catch14':2,
                    'catch15':3,
                    'catch16':4,
                    'catch17':0
                   }

# compute catch trial accuracy for each worker
worker_catch_accuracy = dict()
for worker in df.index:
    iscorrect = []
    for catch_trial in catch_answer_key.keys():
        if catch_trial in df.columns:
            catch_response = df.loc[worker].at[catch_trial]
            if catch_trial != 'catch13':
                if ~np.isnan(catch_response):
                    iscorrect.append(catch_response == catch_answer_key[catch_trial])
            else:
                if catch_response != 'nan':
                    iscorrect.append(catch_response == catch_answer_key[catch_trial])
    worker_catch_accuracy[worker] = np.mean(iscorrect)
    
df['catch_accuracy'] = [worker_catch_accuracy[worker] for worker in df.index]

# %%
# transportability questions 2, 5, 9, and 16 should be reverse scored,
# so that higher score indicates higher transportability
for i in [2, 5, 9, 16]:
    df['transportability' + str(i)] = -df['transportability' + str(i)]

# %%
df['emotionSimilarityJaccardAB'] = makeJaccard(df, 'emotionA', 'emotionB')
df['activitySimilarityJaccardAB'] = makeJaccard(df, 'activityCategoriesA', 'activityCategoriesB')

# %%
print(df.shape[0])
# Out:
# 203

# %%
exclude_list = []

# compile list of workers who had less than 100% catch trial accuracy
exclude_list += df.index[df['catch_accuracy'] < 1].values.tolist()
exclude_list = list(set(exclude_list).intersection(set(df.index.values.tolist())))

print(df.loc[exclude_list].shape[0])
# Out:
# 21

# %%
# append list of workers whose memory descriptions were inadequate
exclude_list += pd.read_csv('../data/exclude_list.csv', header=None)[0].values.tolist()
exclude_list = list(set(exclude_list).intersection(set(df.index.values.tolist())))

print(df.loc[exclude_list].shape[0])
# Out:
# 36

# %%
# text summary stats
df['wordCountA'] = df['memoryA'].apply(lambda x: ts.lexicon_count(x, removepunct=True))
df['wordCountB'] = df['memoryB'].apply(lambda x: ts.lexicon_count(x, removepunct=True))
df['fleschKincaidA'] = df['memoryA'].apply(lambda x: ts.flesch_reading_ease(' '.join(x.split())))
df['fleschKincaidB'] = df['memoryB'].apply(lambda x: ts.flesch_reading_ease(' '.join(x.split())))
df['readabilityA'] = df['memoryA'].apply(lambda x: ts.text_standard(x, float_output=True))
df['readabilityB'] = df['memoryB'].apply(lambda x: ts.text_standard(x, float_output=True))

# %%
# remove workers whose memory descriptions were inadequate
df_clean = df.drop(index=np.asarray(pd.read_csv('../data/exclude_list.csv', header=None)).flatten())

# remove workers who had less than 100% catch trial accuracy
df_clean = df_clean[df_clean['catch_accuracy'] == 1]

# drop columns with all na
df_clean.dropna(axis=1, how='all', inplace=True)

# %%
print(df_clean['wordCountB'].mean())
print(df_clean['wordCountB'].std())
print(df_clean['fleschKincaidB'].mean())
print(df_clean['fleschKincaidB'].std())
# Out:
# 69.51497005988024
# 33.55428191435863
# 76.72047904191616
# 11.757430145425406

# %%
# compute distance features
df_distance = pd.DataFrame()
for col in df_clean.columns:
    if col[-2:] == 'AB':
        if col != 'relateAB':
            df_distance[col[:-2]] = df_clean[col]
    elif col[-1] == 'A':
        if df_clean[col].dtype == np.float_:
            df_distance[col[:-1]] = np.abs(df_clean[col] - df_clean[col[:-1] + 'B'])

# save distance feature matrix along with retrieval strategy
df_distance.to_csv(path_or_buf='../data/free_choice_tv_series_distance_features.csv', sep=',', na_rep='NA', index=False)

# %%
df_no_na = df_clean[~np.isnan(df_clean['transportability1'])]
transportability_sum = df_no_na.sum(axis=1)

# quantiles
q75 = transportability_sum.quantile(.75)
q25 = transportability_sum.quantile(.25)

top25 = transportability_sum >= q75
bottom25 = transportability_sum < q25

# %%
transportability_sum.plot.hist(bins=30)

# %%
makeScatter(df_no_na[top25], 'emotionalSimilarityAB', 'overallSimilarityAB', True, True)

# %%
makeScatter(df_no_na[bottom25], 'emotionalSimilarityAB', 'overallSimilarityAB', True, True)

# %%
makeScatter(df_no_na, 'emotionalSimilarityAB', 'overallSimilarityAB', True, True)

# %%
makeScatter(df_no_na, 'activitySimilarityAB', 'overallSimilarityAB', True, True)

# %%
makeScatter(df_no_na, 'spatialSimilarityAB', 'overallSimilarityAB', True, True)

# %%
makeScatter(df_no_na, 'peopleSimilarityAB', 'overallSimilarityAB', True, True)

# %%
makeScatter(df_no_na, 'emotionSimilarityJaccard', 'overallSimilarityAB', True, True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-169-6e5ca167e960> in <module>
# ----> 1 makeScatter(df_no_na, 'emotionSimilarityJaccard', 'overallSimilarityAB', True, True)
#
# <ipython-input-3-bc462c76ae7e> in makeScatter(df, xcol, ycol, jitter, lineFit)
#       3     fig.set_size_inches(5, 5)
#       4
# ----> 5     plot_df = df[[xcol, ycol]]
#       6
#       7     x = plot_df[xcol]
#
# ~/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ...

# %%
makeScatter(df_no_na, 'activitySimilarityJaccard', 'overallSimilarityAB', True, True)

# %%
for worker in df.index:
    print(worker)
    print('\n')
    print(df.loc[worker, 'memoryA'])
    print('\n')
    print(df.loc[worker, 'memoryB'])
    print('\n\n')
# Out:
# A10Z4QVBJIA914
#
#
# April and Andy hold a dinner party but it ends up being a surprise wedding. Leslie is shocked and concerned. Andy is wearing a football jersey at the alter as they recite their vows to each other.  Chris Traeger serves as best man much to Tom's chagrin. Andy vows to protect April from danger and she says she hates everyone but never hates Andy.
#
#
# Ron Swanson plans to go with his new wife on a honeymoon to the UK but she feels too sick from being pregnant and he has to go alone.  He dreads this and hates being there. Leslie gifts him a very special secret tour where he ends up visiting a whiskey distillery of his favorite scotch, Lagavulin.  He ends up appreciating Scotland and Leslie's very thoughtful gesture.
#
#
#
# A21UA6O7ZFAIQJ
#
#
# ...

# %%
df_distance = pd.DataFrame()
for col in df_clean.columns:
    if col[-2:] == 'AB':
        df_distance[col[:-2]] = df_clean[col]
    elif col[-1] == 'A':
        if df_clean[col].dtype == np.float_:
            df_distance[col[:-1]] = np.abs(df_clean[col] - df_clean[col[:-1] + 'B'])

# %%
features = df_distance.columns.drop('overallSimilarity')
sp_corr = pd.DataFrame({'Feature':features})
sp_corr.set_index('Feature', inplace=True)
sp_corr['SpearmanCorrelation'] = 0
for col in df_distance.columns.drop('overallSimilarity'):
    sp_corr.loc[col, 'SpearmanCorrelation'] = np.abs(ss.spearmanr(df_distance['overallSimilarity'], df_distance[col])[0])

# %%
# Plot
fig, ax = plt.subplots()
fig.set_size_inches(20, 6)
sp_corr.sort_values('SpearmanCorrelation', ascending=False).plot.bar(ax=ax)
ax.set_ylabel('Spearman Correlation')
# Out:
# Text(0, 0.5, 'Spearman Correlation')

# %%
df_no_na['heartwarmingCaptionA'].plot.hist()

# %%
df_distance = pd.DataFrame()
for col in df_no_na.columns:
    if col[-2:] == 'AB':
        df_distance[col[:-2]] = df_no_na[top25][col]
    elif col[-1] == 'A':
        if df_no_na[top25][col].dtype == np.float_:
            df_distance[col[:-1]] = np.abs(df_no_na[top25][col] - df_no_na[top25][col[:-1] + 'B'])

# %%
features = df_distance.columns.drop('overallSimilarity')
sp_corr = pd.DataFrame({'Feature':features})
sp_corr.set_index('Feature', inplace=True)
sp_corr['SpearmanCorrelation'] = 0
for col in df_distance.columns.drop('overallSimilarity'):
    sp_corr.loc[col, 'SpearmanCorrelation'] = np.abs(ss.spearmanr(df_distance['overallSimilarity'], df_distance[col])[0])

# %%
# Plot
fig, ax = plt.subplots()
fig.set_size_inches(20, 6)
sp_corr.sort_values('SpearmanCorrelation', ascending=False).plot.bar(ax=ax)
ax.set_ylabel('Spearman Correlation')
# Out:
# Text(0, 0.5, 'Spearman Correlation')

# %%
df_distance = pd.DataFrame()
for col in df_no_na.columns:
    if col[-2:] == 'AB':
        df_distance[col[:-2]] = df_no_na[bottom25][col]
    elif col[-1] == 'A':
        if df_no_na[bottom25][col].dtype == np.float_:
            df_distance[col[:-1]] = np.abs(df_no_na[bottom25][col] - df_no_na[bottom25][col[:-1] + 'B'])

# %%
features = df_distance.columns.drop('overallSimilarity')
sp_corr = pd.DataFrame({'Feature':features})
sp_corr.set_index('Feature', inplace=True)
sp_corr['SpearmanCorrelation'] = 0
for col in df_distance.columns.drop('overallSimilarity'):
    sp_corr.loc[col, 'SpearmanCorrelation'] = np.abs(ss.spearmanr(df_distance['overallSimilarity'], df_distance[col])[0])

# %%
# Plot
fig, ax = plt.subplots()
fig.set_size_inches(20, 6)
sp_corr.sort_values('SpearmanCorrelation', ascending=False).plot.bar(ax=ax)
ax.set_ylabel('Spearman Correlation')
# Out:
# Text(0, 0.5, 'Spearman Correlation')

# %%
top25.sum()
# Out:
# 32

# %%
bottom25.sum()
# Out:
# 32

# %%
df_no_na.shape
# Out:
# (127, 176)

# %%
df_no_na['emotionalSimilarityAB'].plot.hist()

# %%
# TO DO
# plot spearman correlations for temporally constrained data
