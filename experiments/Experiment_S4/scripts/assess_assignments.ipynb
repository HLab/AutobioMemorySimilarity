# %%
from __future__ import print_function
import psycopg2 as pg2
import numpy as np
import re
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sb
import pandas as pd
import gensim
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from scipy.spatial.distance import jaccard as jaccard_distance
from scipy.spatial.distance import cosine as cosine_distance
from scipy.spatial.distance import hamming as hamming_distance
from scipy import stats as ss
from sklearn.cross_decomposition import CCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as FLD
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.utils import resample
from sklearn.model_selection import StratifiedKFold
from sklearn.svm import LinearSVC
from matplotlib import rc
rc('text', usetex=False)
import csv
import sys
np.set_printoptions(threshold=sys.maxsize)
import os.path
import itertools
import random
import json
from copy import copy
import plotly
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from IPython.display import clear_output
import textstat as ts

# %%
# create descriptive labels for each (phase, trial)
data_type = {'academicCaptionA':np.float_,
'academicCaptionB':np.float_,
'actA':np.float_,
'actB':np.float_,
'activityCategoriesA':np.object_,
'activityCategoriesB':np.object_,
'activitySimilarityAB':np.float_,
'activityTextA':str,
'activityTextB':str,
'age':str,
'analyticalCaptionA':np.float_,
'analyticalCaptionB':np.float_,
'attentionA':np.float_,
'attentionB':np.float_,
'awareA':np.float_,
'awareB':np.float_,
'catch1':np.float_,
'catch10':np.float_,
'catch11':np.float_,
'catch12':np.float_,
'catch13':str,
'catch14':np.float_,
'catch15':np.float_,
'catch16':np.float_,
'catch17':np.float_,
'catch2':np.float_,
'catch3':np.float_,
'catch4':np.float_,
'catch5':np.float_,
'catch6':np.float_,
'catch7':np.float_,
'catch8':np.float_,
'catch9':np.float_,
'causalAB':np.float_,
'centerA':np.float_,
'centerB':np.float_,
'certainA':np.float_,
'certainB':np.float_,
'cherishedCaptionA':np.float_,
'cherishedCaptionB':np.float_,
'childishCaptionA':np.float_,
'childishCaptionB':np.float_,
'closeA':np.float_,
'closeB':np.float_,
'consequenceA':np.float_,
'consequenceB':np.float_,
'consistentA':np.float_,
'consistentB':np.float_,
'controlA':np.float_,
'controlB':np.float_,
'copeA':np.float_,
'copeB':np.float_,
'currentEmotionA':np.float_,
'currentEmotionB':np.float_,
'despicableCaptionA':np.float_,
'despicableCaptionB':np.float_,
'effectiveCaptionA':np.float_,
'effectiveCaptionB':np.float_,
'emotionA':np.object_,
'emotionB':np.object_,
'emotionalSimilarityAB':np.float_,
'english':np.float_,
'episodic1':np.float_,
'episodic2':np.float_,
'episodic3':np.float_,
'ethnicity':str,
'expectedA':np.float_,
'expectedB':np.float_,
'familiarA':np.float_,
'familiarB':np.float_,
'familyA':np.float_,
'familyB':np.float_,
'fatiguingCaptionA':np.float_,
'fatiguingCaptionB':np.float_,
'feedback':str,
'frustratingCaptionA':np.float_,
'frustratingCaptionB':np.float_,
'future1':np.float_,
'future2':np.float_,
'gender':str,
'goofyCaptionA':np.float_,
'goofyCaptionB':np.float_,
'grotesqueCaptionA':np.float_,
'grotesqueCaptionB':np.float_,
'heartwarmingCaptionA':np.float_,
'heartwarmingCaptionB':np.float_,
'helpfulCaptionA':np.float_,
'helpfulCaptionB':np.float_,
'indoorA':np.float_,
'indoorB':np.float_,
'initiatedA':np.float_,
'initiatedB':np.float_,
'instructionalCaptionA':np.float_,
'instructionalCaptionB':np.float_,
'interactA':np.float_,
'interactB':np.float_,
'language':np.object_,
'locationA':np.float_,
'locationB':np.float_,
'maliciousCaptionA':np.float_,
'maliciousCaptionB':np.float_,
'memoryA':str,
'memoryB':str,
'mischievousCaptionA':np.float_,
'mischievousCaptionB':np.float_,
'moreRecentAB':np.float_,
'overallSimilarityAB':np.float_,
'peopleSimilarityAB':np.float_,             
'preciousCaptionA':np.float_,
'preciousCaptionB':np.float_,
'pressureA':np.float_,
'pressureB':np.float_,
'productiveCaptionA':np.float_,
'productiveCaptionB':np.float_,
'promptA2':str,
'promptB2':str,
'properA':np.float_,
'properB':np.float_,
'race':np.object_,
'recallFreqA':np.float_,
'recallFreqB':np.float_,
'regularCaptionA':np.float_,
'regularCaptionB':np.float_,
'relateAB':str,
'relationshipA':np.float_,
'relationshipB':np.float_,
'reoccurA':np.float_,
'reoccurB':np.float_,
'repulsiveCaptionA':np.float_,
'repulsiveCaptionB':np.float_,
'riskA':np.float_,
'riskB':np.float_,
'scholarlyCaptionA':np.float_,
'scholarlyCaptionB':np.float_,
'self-esteemA':np.float_,
'self-esteemB':np.float_,
'semantic1':np.float_,
'semantic2':np.float_,
'sentimentalCaptionA':np.float_,
'sentimentalCaptionB':np.float_,
'settingA':np.float_,
'settingB':np.float_,
'sharedPeopleAB':np.float_,
'similarEnvironmentA':np.float_,
'similarEnvironmentB':np.float_,
'spatial1':np.float_,
'spatial2':np.float_,
'spatial3':np.float_,
'spatialDistanceAB':np.object_,
'spatialScaleA':np.float_,
'spatialScaleB':np.float_,
'spatialSimilarityAB':np.float_,
'stakeA':np.float_,
'stakeB':np.float_,
'standardCaptionA':np.float_,
'standardCaptionB':np.float_,
'stressfulCaptionA':np.float_,
'stressfulCaptionB':np.float_,
'temporalDistanceAB':np.object_,
'temporalScaleA':np.float_,
'temporalScaleB':np.float_,
'temporalSeparationAB':np.float_,
'tiresomeCaptionA':np.float_,
'tiresomeCaptionB':np.float_,
'transportability1':np.float_,
'transportability2':np.float_,
'transportability3':np.float_,
'transportability4':np.float_,
'transportability5':np.float_,
'transportability6':np.float_,
'transportability7':np.float_,
'transportability8':np.float_,
'transportability9':np.float_,
'transportability10':np.float_,
'transportability11':np.float_,
'transportability12':np.float_,
'transportability13':np.float_,
'transportability14':np.float_,
'transportability15':np.float_,
'transportability16':np.float_,
'transportability17':np.float_,
'transportability18':np.float_,
'transportability19':np.float_,
'turkExperience':np.float_,             
'typicalCaptionA':np.float_,
'typicalCaptionB':np.float_,
'understandingA':np.float_,
'understandingB':np.float_,
'usefulCaptionA':np.float_,
'usefulCaptionB':np.float_,
'usualCaptionA':np.float_,
'usualCaptionB':np.float_,
'vividnessA':np.float_,
'vividnessB':np.float_,
'wackyCaptionA':np.float_,
'wackyCaptionB':np.float_,
'wordCloudA':np.object_,
'wordCloudB':np.object_,
'workerID':str}


tempSepDict = {0:'< 24 hrs',
               1:'< 7 days',
               2:'< 30 days',
               3:'< 12 months',
               4:'< 5 years',
               5:'5+ years'
              }

# %%
table_name = 'main'
select_columns = 'workerid, hitid, datastring'
# select_columns = 'workerid, assignmentid, hitid, status, datastring'
pattern_filter = "status IN (4) AND hitid IN ('37ZQELHEQ0AS4P5GYVIPGPGK95INMK', '3MVY4USGB6Z3OJ7ULC1JNQJ9FWSSI9', '38F60IALAGTTWO3T6MH3RRFZVNF0T5')" # grab all entries that successfully completed the HIT

# %%
# run command `heroku pg:credentials:url` within app directory to get the credentials needed below
conn = pg2.connect(user='wuorsurrbxjlgo',
                   password='11b722ee64c73480b7bc2ae64cec8a218dc44f708e16114bc6219e282d505d1a',
                   host='ec2-52-1-20-236.compute-1.amazonaws.com',
                   port='5432',
                   database='ddjst7vhtqfvmf'
                  )
cur = conn.cursor()
cur.execute('SELECT {coi} FROM {tn} WHERE {pf}'.format(coi=select_columns, tn=table_name, pf=pattern_filter))
all_rows = cur.fetchall()
conn.close()

# %%
# Initialize empty data frame
num_entries = len(all_rows)
index = np.arange(num_entries)
columns = list(data_type.keys())
df = pd.DataFrame(index=index, columns=columns)
df = df.astype(data_type)

# %%
# get all question names and initialize empty pandas dataframe
for rwid, rw in enumerate(all_rows):
    jsdict = json.loads(rw[2])
    df.at[rwid, 'workerID'] = jsdict['workerId']
    df.at[rwid, 'hitID'] = jsdict['hitId']
    df.at[rwid, 'assignmentID'] = jsdict['assignmentId']
    df.at[rwid, 'condition'] = jsdict['condition']
    for i, dataEntry in enumerate(jsdict['data']):
        if 'trialdata' in dataEntry.keys():
            if 'response' in dataEntry['trialdata']:
                question = dataEntry['trialdata']['question']
                response = dataEntry['trialdata']['response']
                if (question in df.columns):
                    df.at[rwid, question] = response
            elif 'memoryA' in dataEntry['trialdata']:
                df.at[rwid, 'memoryA'] = dataEntry['trialdata']['memoryA']
                df.at[rwid, 'memoryB'] = dataEntry['trialdata']['memoryB']

# %%
if np.isin('catch13' , df.columns):
    df['catch13'] = [response.lower() if response != 'nan' else 'nan' for response in df['catch13']]
# aggregate 'yesterday' times
df = df.set_index('workerID')

# %%
# catch trial summary

# create dictionary of correct answers
catch_answer_key = {'catch1':0,
                    'catch2':0,
                    'catch3':3,
                    'catch4':10,
                    'catch5':0,
                    'catch6':3,
                    'catch7':1,
                    'catch8':2,
                    'catch9':3,
                    'catch10':2,
                    'catch11':0,
                    'catch12':1,
                    'catch13':'in',
                    'catch14':2,
                    'catch15':3,
                    'catch16':4,
                    'catch17':0
                   }

# compute catch trial accuracy for each worker
worker_catch_accuracy = dict()
for worker in df.index:
    iscorrect = []
    for catch_trial in catch_answer_key.keys():
        if catch_trial in df.columns:
            catch_response = df.loc[worker].at[catch_trial]
            if catch_trial != 'catch13':
                if ~np.isnan(catch_response):
                    iscorrect.append(catch_response == catch_answer_key[catch_trial])
            else:
                if catch_response != 'nan':
                    iscorrect.append(catch_response == catch_answer_key[catch_trial])
    worker_catch_accuracy[worker] = np.mean(iscorrect)
    
df['catch_accuracy'] = [worker_catch_accuracy[worker] for worker in df.index]

# %%
for i in df.index:
    print(i)
    print(df.at[i, 'assignmentID'])
    print(df.at[i, 'catch_accuracy'])
    print('\n')
    print(df.at[i, 'memoryA'])
    print('\n')
    print(df.at[i, 'memoryB'])
    print('\n')
    print(df.at[i, 'wordCloudA'])
    print('\n')
    print(df.at[i, 'wordCloudB'])
    print('\n')
    print(df.at[i, 'activityCategoriesA'])
    print('\n')
    print(df.at[i, 'activityCategoriesB'])
    print('\n')
# Out:
# A3CX0LXFHZ6I3I
# 324G5B4FB4K9KA4GJLJ4AFI4115077
# 1.0
#
#
# The most vivid part of the law and order SVU series is the latest episodes in which Elliot Stabler returns.  It is the episode where the initial part of the episode shows a car bombing with a women being emergency evacuated by ambulance.  Olivia Benson arrives on scene and recognizes that it is Elliot Stabler's wife.  She is quite distraught and shocked at the same time.
#
#
# Once Elliot and Captain Benson had locked eye's, you could sense the pure emotion from them.  A sense of sadness, shock, frustration, and a longing of a long lost friend/partner.  It was truly a surreal moment in SVU history.  The episode continued with Stabler working on the team of SVU (partially) until he let his emotions get the best of him in the interrogation room of a suspect.
#
#
# [['Scary', 'suspensful', 'pain', 'suffering', 'Dangerous'], ['1', '2', '1', '1', '2']]
#
#
# [['uncertain', 'frustrating', 'unsure', 'desperate', 'concering'], ['0', '1', '2', '2', '1']]
#
#
# ['work']
#
#
# ['work']
#
#
# AQZJKEN3MEWJR
# 3F0BG9B9MQZ6H501RTUD27CODEJY75
# 1.0
#
#
# I remember clearly when Andy was discovered sleeping in the pit. He was homeless. It began to rain. It was both amusing and sad. I felt bad for Andy, but also he was responsible for his behavior that led to his misfortune.
#
#
# I remember when Ann went over to Leslie's house. It was an absolute disaster. She was clearly a hoarder. I cannot imagine how someone could let their home get that way. It was amusing in that Leslie seems like the type to have everything in order. Hence, the humor...
#
#
# [['Sad', 'Funny', 'Worrisome', 'Pity', 'Concern'], ['-1', '1', '1', '2', '1']]
#
#
# [['Surprising', 'Concerning', 'Funny', 'uncomfortable', 'confusing'], ['2', '-1', '1', '0', '1']]
#
#
# ['sleep']
#
#
# ['work', 'socializing', 'community/civic/religious']
#
#
# A4HAQO3W6WWYO
# 3AZHRG4CU5WRJR3TH9GEXY6OWZJ305
# 1.0
#
#
# Joffrey is showing Sansa around King's Landing. He brings her outside and she sees her father's head on a pike. Sansa gasps and turns around while Joffrey laughs. Sansa had been all gung-ho about the Baratheon/Lannisters, even wearing her hair like them, but now she sees what they're capable of.
#
#
# Daenarys is participating in a Dothraki ritual in front of the whole clan. She has to eat an animal's heart raw to show she's strong enough to bear a Dothraki child. She has some trouble getting it down at one point and it looks like she may vomit. But she overcomes it and finishes the heart. At the end of the ritual, she yells the name of her child--Rhaego, after her older brother.
#
#
# [['grotesque', 'horrifying', 'devastating', 'sickening', 'terrible'], ['2', '2', '2', '2', '2']]
#
#
# [['gross', 'ritualistic', 'necessary', 'brave', 'bloody'], ['1', '2', '2', '1', '1']]
#
#
# ['other']
#
#
# ['other']
#
#
# A5TNBC5DGSEN1
# 3YMTUJH0DTSDHWJOFP97RE0Z7ACT4S
# 1.0
#
#
# One time Homer said he had an encounter with aliens. He was given a lie detector test. However, the lie detector test blew up. Homer was actually drunk at the time of the encounter though.
#
#
# One time Homer had a realization about peanuts on the couch. Marge went out for groceries, and Homer had only one peanut left. However, he was going to eat it and noticed something was wrong, and he reached under the couch and found only money. He was upset it was not peanuts until he had an inner conversation that made him realize money could buy peanuts. At that moment, Homer learned how money worked even if only for a moment.
#
#
# [['thrilling', 'new', 'scary', 'eerie', 'funny'], ['1', '1', '0', '-1', '1']]
#
#
# [['cute', 'thoughtful', 'funny', 'common', 'stupid'], ['0', '1', '1', '-1', '-1']]
#
#
# ['personal or home leisure', 'socializing', 'other']
#
#
# ['eating']
#
#
# A2PZ8MVVT6TQJM
# 3WMOAN2SRC9EGWXJ2POIR5UKVCPNVZ
# 1.0
#
#
# When Benson was abducted from her apartment by William Lewis and took her to a home.  He tortured her. She ended up beating him and got away. Before she left, she told a woman and her daughter to leave.
#
#
# Lewis had abducted Benson and a little girl. I remember the girl hanging by her hands. Lewis ended up killing himself. No one on the SVU team actually saw it happen, so Benson was accused of shooting him.
#
#
# [['kidnapping', 'torture', 'scary', 'captor', 'victim'], ['2', '2', '2', '-1', '-1']]
#
#
# [['abduction', 'shooting', 'scary', 'suspensful', 'hostage'], ['2', '2', '0', '1', '0']]
#
#
# ['other']
#
#
# ['other']
#
#
# A1NLJ1L4VCQYV2
# 3SNVL38CI54H9H6GEV1X9LPRGA2CKI
# 1.0
#
#
# In one episode, after a fight/argument with Millhouse, Bart starts hanging out more with other kids in Springfield, Nelson to be precise. So, Bart goes over to Nelson's house to hang out. As expected, they find trouble to get into. Nelson grabs a gun (bb i think) and goes into his yard and starts shooting things. After a while Bart starts begging Nelson to let him shoot the gun. Nelson spots a bird in a tree, gives the gun to Bart and then bets Bart that he couldn't hit the bird. Bart takes aim at the bird, gets a case of cold feet and then intentionally overcompensates the guns aim away from the bird to miss it. He then squeezes the trigger and much to his dismay watches as the bird falls out of the nest to its death. Bart drops the gun in shame and feels horrible about what he's done.
#
#
# After watching Ralph not receive any Valentine's gifts from any of the other students, as an act of kindness, Lisa steps up and gives one of her Valentines to him. Ralph completely misreads the gesture and thinks that Lisa is into him. He walks her home, leaves a present for her at her house, and gives her two tickets for a show (as his date). At the show Ralph professes his undying love for her on national tv which sets her off! She rips into him and tells him that she doesn't like him and the only reason that she gave him the valentine or showed up for the date is because she sorry felt for him. Ralph's heart literally breaks.
#
#
# [['outdoors', 'shooting', 'death', 'guilt', 'remorse'], ['-1', '1', '2', '2', '2']]
#
#
# [['romance', 'annoyance', 'humiliation', 'embarrasment', 'guilt'], ['1', '1', '1', '1', '2']]
#
#
# ['personal or home leisure', 'socializing']
#
#
# ['socializing']
#
#
# AJTLLYV8O5FQU
# 3EWIJTFFVPJUTPJQ6TXAGPALNTB0E5
# 1.0
#
#
# I distinctly remember that the Enterprise was in danger of exploding. In the engine room, was a white, gaseous cloud. Captain Jean Luc was standing near the cloud, and began to laugh, hysterically. He then, somehow drew a "smiley," face in the cloud. All of the captains behavior, was out of character, and that was why it is so memorable to me.
#
#
# Data, the android, s on the bridge, with a recurring character named, "Q." Q is an immortal being, who has super powers. Q decides to give Since Data is a robot, and can't experience emotions, Q decides to give Data the gift of experiencing laughter. Data suddenly bursts into peals of laughter, and just as suddenly reverts to his stoic ways.
#
#
# [['Tense', 'Unusual', 'surprising', 'dangerous', 'chaotic'], ['2', '2', '2', '2', '1']]
#
#
# [['surprising', 'funny', 'unique', 'enjoyable', 'laughter'], ['2', '2', '2', '2', '2']]
#
#
# ['other']
#
#
# ['other']
#
#
# A2KW17G25L25R8
# 358010RM5F5JSQBN4VBRP7LIXR7VX1
# 1.0
#
#
# I recall a few episodes where the players needed help with grades, and the teachers helped the students, and other students helped the football players pass the classes.
#
#
# I recall a few details about games they won, and how they reacted after the games. I remember a few games they won that were very important games. I recall the coaches wife is also a teacher at the school.
#
#
# [['Players', 'Football', 'students', 'teachers', 'helping'], ['2', '2', '2', '2', '2']]
#
#
# [['Winning', 'football', 'teachers', 'coaches', 'reactions '], ['2', '2', '2', '2', '2']]
#
#
# ['other']
#
#
# ['other']
#
#
# A3FBC5W56LKQXL
# 3D3VGR7TA1RFJLNSBMZTHU7B5PJR3S
# 1.0
#
#
# When the main character and his wife went to look at their pile of money in the rental unit where they kept it. They operated a car washing business to help them launder their drug money, and the money would wait in the rental unit until they needed to launder it. It was a huge pile, 2 million dollars.
#
#
# When a character in the story, Uncle Tio, blew up his enemy. Uncle Tio was in a wheel chair and could only communicate with a bell. His enemy would come visit him in the nursing home to torment him (verbally). The main character convinced Uncle Tio to hide a bomb in his wheelchair and blow the man up with himself.
#
#
# [['money', 'rich', 'illegal', 'dealer', 'criminal'], ['1', '1', '2', '1', '2']]
#
#
# [['murder', 'suicide', 'explosion', 'killing', 'bomb'], ['2', '2', '2', '2', '2']]
#
#
# ['other']
#
#
# ['other']
#
#
# A2MYLV7DGUL42B
# 38JBBYETQPMBSD1RPUKCSS0Y461E4B
# 1.0
#
#
# When Walter lets Jesse's girlfriend choke on her own puke. She ends up dying from choking. Walter does not even attempt to save her. She was on drugs.
#
#
# Walter witnesses a collision of two planes. The girlfriend he let die was the daughter of the air traffic controller. He was upset which led to the air collision. Walter begins to think about what he is doing.
#
#
# [['sad', 'pathetic', 'wrong', 'heartless', 'unforgiving'], ['0', '0', '1', '1', '0']]
#
#
# [['distracted', 'unprofessional', 'sad', 'surprising', 'shock'], ['2', '1', '1', '1', '1']]
#
#
# ['other']
#
#
# ['work']
#
#
# A38AF7RJM28PGX
# 3F6HPJW4JECV6Z8V6GVULJA0RY0W27
# 1.0
#
#
# Homer was working at the nuclear plant and his inattention to an alarm caused a nuclear incident. He was busy having a snack and taking a nap. A red light alarm was flashing and he did not notice it. Then the crisis ensued and everyone had to evacuate.
#
#
# every year I watch the simpsons for halloween. I enjoy the treehouse of horror. I love it because nothing is what it seems and everything is normal by the end of the show. No matter what kind of monsters or ghouls they become by the end of the show it is all okay.
#
#
# [['expected', 'dumb', 'lazy', 'unaware', 'doofus'], ['0', '1', '1', '0', '1']]
#
#
# [['tricky', 'different', 'changelings', 'spooky', 'mysterious'], ['1', '2', '1', '1', '1']]
#
#
# ['sleep', 'work', 'eating']
#
#
# ['other']
#
#
# A111ZG78153D48
# 3JPSL1DZ5TBUO8ULRUXMVIG7A82NAO
# 1.0
#
#
# April and Andy invite the whole department and other various town members to a dinner party. They ask everyone to bring things, some more obscure than others - for example, Ben was to bring a 3D movie and a 3D-capable TV, while Chris was to bring a cake. Chris didn't bring a cake, though, he brought a vegetable loaf, which made Ron mad. When everyone arrived for the dinner party, they discovered that April and Andy were actually getting married. Leslie tried to talk April into it but she wasn't listening. You also find out in this scene that April's middle name is Roberta. Leslie also tried to get Ann to come sabotage the wedding but Ann refused.
#
#
# Christ broke up with Ann but Ann didn't know and thought Chris was cheating on her. So, when Leslie and Ron go to Indianapolis and stop at Chris' apartment, Leslie tries to find proof of his infidelity. Such as his pink swim cap and his women's razor, which are both explained away as a breast cancer cap and women's razors being better at shaving the contour of the shin.
#
#
# [['Suprise', 'Lovely', 'Sweet', 'Wedding', 'Party'], ['1', '-1', '1', '2', '2']]
#
#
# [['Snooping', 'Cheating', 'Breakup', 'Confusion', 'Arguing'], ['1', '2', '2', '1', '1']]
#
#
# ['socializing', 'other']
#
#
# ['socializing', 'other']
#
#
# AONSG5WOC3OX0
# 3YOH7BII0AJD8QCG5CW2ZDDG1IRKV0
# 1.0
#
#
# My memory for the TV series Game of throne is pretty vivid. I can recite most if not all characters in the film as well as the overall plot. In general, there are nine noble houses that try to compete for the rule of Westeros. Lots of political warfare, betrayal, and alliance lead Daenerys Targaryen to end up burning kings landing to the ground. The north becomes independent and Bran was chosen as the ruler of the six kingdoms. The biggest hype in the series was probably arya stark kill off the Night King.
#
#
# The Night King turns Viserion into a white walker. Viserion was Daenery's old dragon and is now Night King's strongest weapon. Viserion was knocked down by Night King's spear. This was accomplished at the end of season 7. The episode was "Beyond the wall"
#
#
# [['destruction', 'madness', 'surprising', 'unexpected', 'disappointment'], ['2', '2', '2', '2', '2']]
#
#
# [['surprising', 'impressed', 'hyped', 'afriad', 'unexpected'], ['2', '2', '2', '2', '2']]
#
#
# ['community/civic/religious']
#
#
# ['sports or exercise', 'community/civic/religious', 'pets']
#
#
# A33IDNK3S0T6VZ
# 3IFS6Q0HJJV6A35OBE6LBAEWAFKSIE
# 1.0
#
#
# I specifically remember when Walter let Jesse's girlfriend, Jane, die of a heroin overdose.  When Walter let himself into the apartment they were sleeping in, she was still alive, but choking on her own vomit.  Rather than try to save Jane from imminent death, Walter allows her to choke to death when he accidentally knocks her onto her back.
#
#
# Walt, Jesse, and Todd were in the desert and they hijacked methylamine from a cargo train to be able to continue to make their product.  They successfully hijacked the cargo train, but there was a young boy riding his dirt bike in the desert at the same time and at the same location, and witnessed them hijack the train.  Todd, without even caring that it was a child, immediately shot and killed the kid once he realized the kid saw them hijack the train.  It was a very brutal and very intense scene.
#
#
# [['Horrifying', 'Sad', 'Surprising'], ['2', '2', '1']]
#
#
# [['Unnecessary', 'Brutal', 'Shocking', 'Disturbing'], ['1', '2', '2', '2']]
#
#
# ['sleep']
#
#
# ['other']
#
#
# AAIQK5N5KRHRY
# 3TYCR1GOTDV51GZ8R9X6ZJ3REYLLZX
# 1.0
#
#
# So, I remember a handful of events from the series...but I'll draw on one of my personal favorite episodes, for its absurd humor/suspense -- the one when Tuco Salamanca kidnapped Jessie Pinkman and Walter White, and took them to an undisclosed location far in the desert (I believe it may have been Tuco's uncle's house, whose name always escapes me, unfortunately...but, yeah -- the guy who had a stroke who's wheelchair-bound). Anyway, Jessie and Walter are going to try poisoning Tuco with ricin (potential ricin poisonings being a reoccurring trope on the show...'til Lydia finally gets hers, with her damn chamomile tea w/stevia). Walter and Jessie first try poisoning Tuco's tortilla, when he's turned around not looking at them busy cooking the tortillas -- but the uncle is the best sly character, totally notices and knows what they're up to, and tries warning Tuco with his signature "ding-ding-ding!!" doorbell/service bell he has installed on his wheelchair, and by acting weird. "Me first, uncle!" - Tuco says to the uncle when he's about to take a bite out of the poisoned taco (as I'm always saying "Me first, kitties!" to my cats when I want to eat before them, lol). The uncle subsequently makes a scene, I believe knocking the tortilla to the floor, so neither he nor Tuco end up poisoned. So, since THAT didn't work, Jessie and Walter then trying egging on Tuco to have a snort of some "crystal blue persuasion" with a pinch of ricin Walter brought with them, in the hopes of poisoning him that way. Too bad Jessie tells him there's some "chili powder" in it, to which Tuco subsequently tells him he "hates chili powder!" -- and decides against the imbibing. Meanwhile, Hank picked up on Tuco's trail out to this middle of nowhere location (why would he know Jessie and Walt are with him? Since he don't know nothin' yet); there's a shoot out with Tuco, leaving Hank wounded...yeah, I'm not remembering all of this so perfectly, actually! lol. Like, did Hank kill Tuco?! Actually don't a hundred percent remember...though I remember Walter and Jessie hiding, and a ditch in the dirt...and all very dramatic and suspenseful. (Honestly, there are other episodes/events I have better recollection of than this...I just chose this one, 'cause it's one of my fave episodes.)
#
#
# The in recovery-until she had to go and meet-Jessie Pinkman-Jane, gets Jessie (is it Jessie or Jesse?) into heroin. When they're both stoned in bed one night,  Walter White happens to break into Jessie's apt. (to get either money or meth or both Jessie/Walter's hiding, don't 100% remember -- it was under the kitchen sink?) the moment Jane overdoses/chokes on her own vomit, and stands over her while it happens -- "I watched Jane die," he later shockingly, mockingly admits to Jessie in their final moments together -- doing nothing to save her. When Jessie wakes up to her dead body the next morning, one of the first things he can't stop doing is listening to her voice on her recorded voicemail inbox message over and over and over and over again, he's in so much shock and pain. Mike is assigned by Saul to come "clean it up" -- make what happened, look like it didn't happen. Like so many events brilliantly interlinked on the show, Jane's death from heroin directly causes her father, distracted and beside himself with grief, to accidentally cause two planes in the air above Albuquerque to crash, causing the "question" of the singed, one-eyed pink teddy bear we see fall from the sky in the opening episode of the season, to finally come full circle and be "answered."
#
#
# [['Suspenseful', 'Fun', 'Funny', 'Intense', 'Nail-biting'], ['2', '1', '1', '2', '1']]
#
#
# [['Disgusting', 'Awful', 'Depressing', 'Shocking', 'Evil'], ['1', '2', '2', '2', '2']]
#
#
# ['eating', 'preparing food', 'personal or home leisure', 'socializing', 'family care', 'other']
#
#
# ['sleep', 'personal or home leisure', 'socializing', 'house care', 'other']
#
#
# A1D49NVJ3PJDJ2
# 3A1PQ49WVIT6KOVASD9GFXQ8K5K1H8
# 0.8888888888888888
#
#
# The show is very funny with all the characters in the show. The show is about a cartoon family not based on a real story. The family goes about their lives and drama happens.
#
#
# I remember when the family goes to a museum and Homer's ambition is questioned. They go to the museum and a lot of funny things happened as a result.
#
#
# [['Funny', 'Amusing', 'Happy', 'Help', 'Family'], ['-1', '-1', '0', '0', '1']]
#
#
# [['Funny', 'Social', 'Happy', 'Health', 'Family'], ['-1', '-1', '0', '0', '1']]
#
#
# ['socializing']
#
#
# ['socializing']
#
#
# A3V1960E62U3JR
# 3Z4AIRP3C7P36EVPXHR2IJE28OZX1F
# 1.0
#
#
# I remember the episode Ron, Donna, Leslie, Tom, and Ann go to Ron's cabin to hunt.  Ron is not pleased about the women joining, if I recall it is a "male" office tradition. Someone accidentally shoots Ron and no one will fess up to it.  Eventually we find out Tom shot Ron and he is absolutely terrified.  I also remember Donna's truck getting shot and her being VERY upset.  Ann ends up patching up Ron and he doesn't find out Tom shot him.
#
#
# An episode in the first season revolves around the pit in Ann's back yard.  Leslie has to hold public forum and gets a lot of dumb folks like usual.  Ann is there and asks Lesie to do something about the pit as it is dangerous.  I believe we find out in this episode that Andy has fallen into the pit at least once and hurt himself.  Leslie is super excited about the idea and makes it her goal to turn the pit into a park.
#
#
# [['Stressful', 'Uncommon', 'Amusing'], ['2', '0', '0']]
#
#
# [['Funny', 'Clerical'], ['1', '-1']]
#
#
# ['other']
#
#
# ['community/civic/religious']
#
#
# A16E38HXNQBLCU
# 3DOCMVPBTOQ18ROA0Y2RHO079I5NNI
# 1.0
#
#
# There was one episode where Andy goes to the doctor. In the episode, he has to visit specialists in the hospital because he hasn't been to the doctor in a while. He lists various things that are wrong with him to the doctor, while the doctor listens. He describes using the restroom and having to wipe and wipe and wipe, to the amusement of April, who is there with him.
#
#
# Ron Swanson goes to a restaurant on a road trip, and asks the waiter to bring him bacon and eggs. He says "Bring me all the bacon and eggs." Then he stops the waiter and says "Hold on, you may have heard me say 'bring me a lot of bacon and eggs'. I said bring me ALL the bacon and eggs."
#
#
# [['funny', 'shocking', 'gross', 'amusing', 'intimate'], ['2', '0', '0', '1', '2']]
#
#
# [['relatable', 'funny', 'hungry', 'relaxed', 'amusing'], ['2', '0', '1', '1', '0']]
#
#
# ['other']
#
#
# ['eating', 'preparing food']
#
#
# AOLQA0CBEC46G
# 37TRT2X24R33OS8SIA5QXMJWJCQBJN
# 1.0
#
#
# Olivia is a child of a rape her mother experienced, and was abducted from her apartment by a rapist. He tortured her and tied her up with duct tape. He kept her in a basement. Detective Stabler saved her before the rapist could kill her
#
#
# A girl who babysits kids told Oliva that there was a family that she watches kids for and that she was worrid about them because they had not called her as usual. Oliva decides to check out the family and find that they are being held hostage in their home. There were 3 people who were holding them hostage
#
#
# [['ABDUCTED', 'BASEMENT', 'RAPIST', 'STABLER', 'TOURTUE'], ['2', '2', '2', '2', '2']]
#
#
# [['BABYSITER', 'RESCUE', 'HOSTAGE', 'FAMILY', 'CURIOUS'], ['2', '2', '2', '2', '2']]
#
#
# ['sleep', 'work', 'personal or home leisure']
#
#
# ['personal or home leisure', 'house care', 'family care']
#
#
# A21S5KBNLY5YZB
# 3MB8LZR5BG5ACL0MR8UWC4FEAS0KL8
# 1.0
#
#
# The Battle of the Bastards is one big event that happened in the show where Jon Snow fought Ramsay Bolton over control of Winterfell. There was a lot of action in this episode and epic fighting, when Jon is about to be defeated and crushed to death with his army being surrounded by Ramsay's and saved at the last minute when Sansa shows up with Littlefinger and another army to save them. The scenes with Jon running and all of the arrows missing him as if by magic also really stands out. At the end Jon wins and defeats Ramsay to become the King of The North in Winterfell. There was also the part where Jon's youngest brother is set loose by Ramsay and goes running at him and is killed by one of Ramsay's arrows from a distance behind as he's running in a straight line toward Jon on the opposite side of the battlefield.
#
#
# The battle at Winterfell in season 7 episode 3 as the night king reaches Winterfell with the host of white walkers. The battle starts with them sending the Dothraki horde out on horse to meet them with firey swords that are quickly defeated as they fail to make any impact, there is a lot of action, the northern little girl that's a lord gets killed by a giant but takes it down while dying. Winterfell gets infiltrated by white walkers and there is a standoff in the garden of Winterfell with the god's wood tree. Bran Stark waits under the tree and is seemily going to surrender to the night king who approaches him.  Then when all hope is lost Arya Stark leaps out of nowhere and kills the night king from behind with a  a dragon glass dagger that instantly kills him and he turns to ice and shatters. When the night king is killed all the white walkers also die and the battle is over and won by the defenders of Winterfell.
#
#
# [['battle', 'bastards', 'king', 'north', 'Winterfell'], ['2', '2', '2', '2', '2']]
#
#
# [['battle', 'realm', 'winter', 'zombies', 'dragons'], ['2', '2', '2', '2', '1']]
#
#
# ['other']
#
#
# ['other']
#
#
# AIAZ6ETJTQGRI
# 3HPZF4IVNN5CTMVXIA2OIT42E2YCYQ
# 0.6666666666666666
#
#
# pubg is good game the mobile so i very like the game eny time i will play 100 member land in asia map kill final win so i adict this game so i was very impress game so i like the game so i play gain again platinam gold diamaond crown ace tier push pubg
#
#
# tv show stream in the game i was watching so good content chanel so addd controler and stream good so i want to tv watching many time so need improovment so i will call pubg player watch pubg stream tv
#
#
# [['pubg', '100meber participate', 'tier push', 'stream tv', 'good game'], ['2', '2', '1', '0', '2']]
#
#
# [['i watch stream tv', 'watch many time', 'content chanel', 'stream good', 'i call player watch'], ['2', '0', '-2', '2', '0']]
#
#
# ['sports or exercise', 'socializing']
#
#
# ['work', 'eating']
#
#
# A11F3MA5FWH6SJ
# 3L70J4KAZHYL2W3820JJZD4DW55AD0
# 1.0
#
#
# I recall Law & Order SVU being an NYPD based detective show. They usually went out to murder scenes to try to discover evidence to support their cases. There are several seasons of this show. The show has also won several awards as well.
#
#
# I remember an episode where a judge had got shot. They showed the crime scene and partially discussed about it. Olivia also had adopted Noah. This was also the last episode of Amaro.
#
#
# [['awesome'], ['1']]
#
#
# [['Unforgettable'], ['2']]
#
#
# ['other']
#
#
# ['other']
#
#
# A26OG9W41G0W52
# 3Q5ZZ9ZEVPRCFVV0QWHM5AAQTV858A
# 1.0
#
#
# I remember of a scene where Smash lead a walkout during practise because of a racist comment made by coach Miguel. He unites all the black players to take a stand. Smash always stands up for what he believes in. But later comes back with the guys for a big game. He makes it clear to the coach that they were offended by the comments and that It should never happen again.
#
#
# Tami and coach knock heads when she is offered her dream job in Philadelphia and coach is offered a job as the head coach of east west super team. Coach does not like the idea but Tami stands her ground.
#
#
# [['open', 'caring', 'selfish'], ['2', '2', '2']]
#
#
# [['caring', 'deserving', 'open ', 'loving'], ['2', '2', '2', '2']]
#
#
# ['sports or exercise', 'socializing']
#
#
# ['work', 'sports or exercise']
#
#
# A2RLOB9VH2XSRT
# 35H6S234SBCPBHCCXHKOLWEZN5T65A
# 1.0
#
#
# The most memorable moments I have from Breaking Bad come from the final episode.  The moments when Jesse escaped and gained his freedom, when the rotating machine gun wiped out the gang, and the final wrap up of the series were all part of the whole experience.  But the memory that stands out the most is Walt being shot and the playing of "Baby Blue" at the very end.  That moment was truly the perfect handling and summary of what Walt's life was like since he began cooking.
#
#
# The killing of Hank, Walt's brother in law was such a dramatic and surprising event that it became an iconic moment for me.  Despite Walt begging Jack not to kill him, Hank was killed anyway.  Hank was truly a good guy and such an important member of Walt's family that his death was a devastating and memorable event.
#
#
# [['surprising', 'unexpected', 'sad', 'deserved', 'final'], ['1', '1', '-1', '2', '2']]
#
#
# [['expected', 'sad', 'undeserved', 'devastating', 'necessary'], ['2', '1', '1', '2', '1']]
#
#
# ['other']
#
#
# ['work']
#
#
# A3AZ8P0AON4FXV
# 3DR23U6WE6QV9YGH4VLK00CQK24TE2
# 1.0
#
#
# I recall Captain Picard waking up from the 'coma' in Inner Light.  I remember everyone surrounding him.  It was an emotional episode and moment.  I remember a lot about the episode.
#
#
# I remember Picard having beem assimilated and addressing the rest of the bridge crew.  It was a shocking moment.  It was a great cliffhanger with Riker giving the order to fire.
#
#
# [['Glad', 'relieved', 'happy', 'involved'], ['1', '1', '0', '2']]
#
#
# [['shocked', 'apprehensive'], ['1', '1']]
#
#
# ['sleep']
#
#
# ['other']
#
#
# AOHCSIN8IW046
# 33OOO72IVIXGC0W384FPACCNZQHCTI
# 1.0
#
#
# I remember seeing a burnt toy in a pool at the beginning of every episode in that season. Jessie had a girlfriend, Jane. At the time Walter did not like them together. One night Jane was overdosing, and Walter could have helped her, but instead let her die because it was better in the end for their business. Jane's father was an air traffic controller and when he found out he was unable to do his job and that is what led to the plane crash that was referenced in the beginning of each episode.
#
#
# Another memory from the show was when Walter was making so much money and he needed to find a way to hide it. Him and his wife bought and fixed up a car wash to be a front for all the money he was making. I just remember them having to find so many places to store it.
#
#
# [['shocking', 'sad', 'unbelieveable', 'upsetting'], ['2', '2', '1', '2']]
#
#
# [['creative', 'logical'], ['2', '2']]
#
#
# ['other']
#
#
# ['work']
#
#
# A3Q9H7A8J8GR01
# 3NS0A6KXC5KPFOL7GI0QMRYJII2GZR
# 1.0
#
#
# A teacher who barely makes enough to take care of his family learns that he has terminally ill with cancer. The lead actor's facial expression was what hooked me on to the story.
# Also when Jesse fails to get even the job of swinging ad banners and his frustration.
#
#
# His wife being unfaithful to him and the way she reacts to the softness of the bathroom carpet, her feeling of loss and remorse; her feeling of vindication.
#
#
# [['heartrending', 'sad', 'shocking', 'pitiable'], ['1', '2', '2', '2']]
#
#
# [['shocking', 'sad'], ['2', '1']]
#
#
# ['other']
#
#
# ['other']
#
#
# A1UNUY95MSK393
# 3DBQWDE4Y7AXI2I4WY65N70LIXKN57
# 1.0
#
#
# Maeby wound up living in a retirement community while pretending to be an old woman.  George Michael visited her a few times while she lived there.  She really leaned into the character and wore clothing and wigs to appear as an old lady.  She was avoiding her family and some responsibilities through this time.
#
#
# David Cross is a never nude.  Even when showering, he keeps at least one article of clothing on.  Or when he is alone with Lindsay and should be comfortable with nudity, he keeps clothing on.  This isn't a specific scene or anything as his "never nude" characteristic is shown throughout the series.
#
#
# [['Ridiculous', 'Absurd', 'Abnormal', 'Amusing'], ['1', '1', '0', '1']]
#
#
# [['Absurd', 'Hilarious', 'Irregular'], ['2', '1', '1']]
#
#
# ['personal or home leisure', 'community/civic/religious', 'house care', 'other']
#
#
# ['sleep', 'personal or home leisure', 'grooming or dressing', 'other']
#
#
# A5SW7LKS5X50A
# 37Q970SNZFKVAX9Q37LFJBXATL01S2
# 1.0
#
#
# My favourite character is Daenerys Targeryan and her dragons . I like the scene that the dragon first fires to protect the mother of dragons . next I like the battle between the  army of living and the army  of dead. I love the scene that arya stark  kills the dead king.
#
#
# The battle between the army of living and the army of dead is the best battle. The dragons also fight with each other . almost the dead captured the living and the battle was interesting. At last Arya stark killed the dead king with  sword  from his back .The dead king try to kill bran stark but Arya stark killed him and the battle comes to end.
#
#
# [['dragon', 'fire', 'kill', 'fight', 'mother'], ['2', '2', '0', '1', '1']]
#
#
# [['battle', 'dragon', 'war', 'king', 'fight'], ['1', '2', '2', '2', '1']]
#
#
# ['other']
#
#
# ['other']
#
#
# AB3L4DBGHX7PG
# 39GXDJN2OUQTDPAFWNZZ984P6OP8V9
# 1.0
#
#
# I have a vivid memory of Daenerys relationship with Khal Drogo. More precisely, I remember well their intimate relationship and their different approach and expectations of the same. It is very striking the way Daeneris showed Khal the beauty of a different approach to intimacy. It greatly influenced their overall relationship and, it seems to me, her dominance.
#
#
#
#
# I am struck by the scene when Arya Stark sees face masks for the first time. I was thrilled by the masks themselves, as well as Arya’s reaction to them. And I was fascinated when she used them later. This greatly contributed to the description of her personality and character.
#
#
# [['clever', 'patient', 'passionate', 'intimate', 'emotional '], ['2', '1', '0', '0', '1']]
#
#
# [['patient', 'persistent', 'determined', 'brave', 'intelligent'], ['1', '1', '2', '2', '2']]
#
#
# ['personal or home leisure', 'other']
#
#
# ['other']
#
#
# A2OU4EI5K6LZ0Z
# 3018Q3ZVOJ2F36MDK1E342LHB3KARO
# 1.0
#
#
# Captain Picard has been abducted from the Enterprise by the Borg. The crew is confused and unsure what to do. The Borg vessel hails the Enterprise. Dramatic music plays, and a Borg silhouette walks toward the viewscreen camera. A red laser traces the movement of the silhouette's head, occasionally creating an artifact on the viewscreen. The Borg figure emerges into the viewscreen, looking very much like Captain Picard, and says "I am Locutus, of Borg."
#
#
# The Enterprise is carrying cargo, which includes samples of a pathogen. Doctor Pulaski goes to examine the condition of the stasis field that is supposed to keep the pathogen from growing. She expresses displeasure to Data that the pathogen has been engineered by "eager beavers." Data asks what Pulaski means by "eager beavers" and she explains that eager beavers are genetic engineers who have tweaked the pathogen "to see just how bad bad can get."
#
#
# [['Anxious', 'Violation', 'Terrifying', 'Totalitarian', 'Authoritarian'], ['2', '2', '2', '2', '2']]
#
#
# [['Funny', 'Instructional', 'Annoyed', 'Ethical', 'Anxious'], ['1', '1', '1', '2', '1']]
#
#
# ['community/civic/religious', 'grooming or dressing', 'other']
#
#
# ['work', 'other']
#
#
# ASA7IFS066IV9
# 3DIP6YHAPD4CBEOT1XAP94G36PN8EW
# 1.0
#
#
# The most specific memory I have is after Daenerys marries Khal Drogo, she and her brother Viserys are traveling with the Dothraki. One evening, Viserys is particularly boisterous about how he is the rightful king of Westeros and he gave Dany to Khal Drogo so he and his Dothraki riders would help him raise an army to overthrow the Baratheon's and reclaim is seat on the Iron Throne. Khal Drogo then melts a gold chalace and pours it on Viserys' head saying " crown for king"
#
#
# Another memory is when Joffrey marries Margery Tyrell and after humiliating Tyrion at his wedding feast, Joffrey starts to choke. His face turns red, then blue. The blood vessels in his eyes burst and Jamie and Cersei scream and run to Joffrey's side. He ultimately dies and Cersei blames Tyrion for poisoning her son.
#
#
# [['surprising', 'thrilling', 'funny', 'deserved', 'pivotal'], ['2', '0', '-2', '0', '2']]
#
#
# [['satisfying', 'surprising', 'vengence', 'cunning', 'pivotal'], ['2', '2', '2', '1', '2']]
#
#
# ['other']
#
#
# ['eating', 'socializing', 'community/civic/religious']
#
#
# A1EZV3Q6PGMQTY
# 39U1BHVTDM3SZ00KFB4OH98TTJLT3U
# 1.0
#
#
# I remember when Riker fell in love with one of the people from the androgynous society. She identified as female even though it was illegal to do so. As I remember, it didn't end well for her. It was also NG's sad nod at a gay episode.
#
#
# I remember the episode where the crew finds the borg who's been separated from his group. They name him Huge. They help to rehabilitate him and help him remember himself. They want to use him to wipe out the borg, but then start to like him.
#
#
# [['painful', 'stressful', 'frustrating', 'caring', 'oppressive'], ['1', '0', '-1', '1', '2']]
#
#
# [['dangerous', 'surprising', 'kind', 'transformative', 'ethical'], ['1', '1', '0', '1', '2']]
#
#
# ['socializing', 'other']
#
#
# ['other']
#
#
# AD5PA88V82M81
# 3X0H8UUIT20OBYPT0VA0C1N4PYKWS7
# 1.0
#
#
# king joffrey was poisoned from the poison that sansa had on her necklace.
#
# jon snow is actually a targaryian and daenerys is his aunt.
#
# daenerys promised she would spare kings landing but instead burned the majority of it.
#
#
#
#
# daenerys and jon snow fought the night king on top of rhaegal and drogo. daenerys other dragon viserion was killed by the night king. then viserion was pulled up from the waters and reanimated by the night king to join the army of dead being used to fight against daenerys and jon snows army.
#
#
# [['death', 'happiness', 'joy', 'sadness', 'promising'], ['2', '2', '2', '2', '2']]
#
#
# [['great', 'amazing', 'fascinating', 'shocking', 'scared'], ['2', '2', '2', '2', '2']]
#
#
# ['socializing', 'other']
#
#
# ['other']
#
#
# A6717SDXOR1OP
# 3HWRJOOET6EUUY32FVGUQVG4IKMSEA
# 1.0
#
#
# Ramsey is in the dungeon tied up, Sansa Stark is with him. She threats him and taunts him. Then you hear the dogs, Ramsey thinks they are loyal to him and is sure they won't hurt him. The dogs tear him to pieces and kill him.
#
#
# Bran has a vision, a young boy is having a panic attack, he's on the ground and repeating "hold the door" then you see Odor against a door holding it so the Night creatures don't pass.
#
#
# [['Death', 'Revenge', 'Dogs', 'Disbelieve', 'Cruelty'], ['2', '2', '2', '1', '2']]
#
#
# [['Sacrifice', 'Creatures', 'Pain', 'Fear', 'Hero'], ['2', '1', '2', '2', '2']]
#
#
# ['other']
#
#
# ['other']
#
#
# A3K36OLIGLEP6D
# 3A7Y0R2P2P0A1VBTN6X8MJAO27DXJ1
# 1.0
#
#
# In the episode, I'm thinking of was similar to the Chris Brown Rihanna situation. A Singer is beat up by her boyfriend during a studio session. By the end of the episode Micha goes back to her boyfriend Caleb. He kills her on a yatch while they are on vacation.
#
#
# Another episode I remember is when an incel was killing and attacking women for turning him down. He picked one woman because she chose a black man over him. Another woman worked in a coffee shop because she chose a "loser" over him. He called them sluts. He had imaginary relationships with the majority of these women.
#
#
# [['Cruel', 'Abusive', 'Demeaning', 'Controlling', 'Violent'], ['2', '2', '2', '2', '2']]
#
#
# [['Egotistical', 'Angry', 'Pathetic', 'Projection', 'Assaulting '], ['2', '2', '2', '2', '2']]
#
#
# ['work', 'socializing', 'other']
#
#
# ['personal or home leisure', 'socializing', 'other']
#
#
# A1G5UODTVW13MM
# 3IOEN3P9S8VQNZBTWUICI61IBMK16D
# 1.0
#
#
# in the last episode it is the scene that he is killed in. he parks his car outside of the building. he goes in to save jesse. while inside he uses his remote to start the machine gun he setup in the car. it shoots everyone in the building and he is also shot buy it.
#
#
# it was a scene where jesse had to get rid of a body. he is kind of an idiot so it ended up creating a huge problem. he put a body in his bathtub and tried to dissolve it with acid. the acid ate through the tub and ceiling and crashed onto the lower floor.
#
#
# [['fear', 'sadness', 'heroic', 'excitement', 'calm'], ['2', '2', '2', '2', '2']]
#
#
# [['worry', 'panic', 'disgust', 'grossness', 'fear'], ['2', '2', '2', '2', '1']]
#
#
# ['other']
#
#
# ['other']
#
#
# ATTAQA9KLECBA
# 3VELCLL3GLVM6S44XNLGCCEV4VNF1E
# 0.8888888888888888
#
#
# Star trek is a television series. This is television series which is based on fantasy. Most of the scenes of this series are computer graphic based. More viewers are available to this television series. This is so popular among US people.
#
#
# Star trek next generation is wonderful television series. I like most of the characters in this series. Most of the scenes are made using computer graphics. I remember most of the scenes of this series.
#
#
# [['fantasy', 'real', 'action', 'trap', 'involve'], ['1', '0', '1', '1', '0']]
#
#
# [['character', 'real', 'adventure', 'creative', 'space'], ['1', '1', '1', '2', '1']]
#
#
# ['socializing']
#
#
# ['socializing']
#
#
# A1F91S7HGQPDO7
# 3OF2M9AATH0UHAHQ69L5KJQCPWIKZR
# 1.0
#
#
# I remember the scene when Marge asked Homer to imagine about marrying to him. Homer imagined that he married himself in a wedding. Then there was another yellow woman came to disrupt the wedding with the talking dog. Then he saw himself on the window. Finally the imagination vanished.
#
#
# Bart hammered the candy. Homer came in and said he would punish Bart. But then the ice cream truck came and Homer was excited. After Homer and Bart got the ice cream, Homer forgot what he needed to do. Bart tried to avoid the punishment and told Homer that he was supposed to talk about his time in Jury duty.
#
#
# [['imaginative', 'funny', 'ridiculous', 'goofy', 'childish'], ['1', '2', '2', '2', '2']]
#
#
# [['Childish', 'Goofy', 'Funny', 'Smart', 'Ignorant'], ['2', '2', '2', '2', '0']]
#
#
# ['other']
#
#
# ['other']
#
#
# ACZCCLKP1S5B4
# 3UOUJI6MTEQJFBMNZ51MTLJZJU8UX5
# 1.0
#
#
# I remember the scene where the two main characters were trying to get rid of a body by dissolving it in acid.  The acid ended up eating through the receptacle that was holding the body. Chunks of body parts started spilling all over the place.  They were trying to clean it up, and it was so disgusting.
#
#
# I remember the scene when Jessie came to his friends house after he escaped from the hole.  He looked terrible, and his friends told him to take a shower.  There was blood and mud and everything running down the drain.  Then when he got out he shaved all of his beard off.
#
#
# [['Disgusting', 'Frantic', 'disorganized', 'bloody'], ['2', '2', '1', '2']]
#
#
# [['Sad', 'Dirty', 'awkward', 'depressing'], ['2', '1', '0', '2']]
#
#
# ['other']
#
#
# ['grooming or dressing']
#
#
# A2GU5RTKQWJXNA
# 37TRT2X24R33OS8SIA5QXMJWJ8FBJ4
# 1.0
#
#
# Homer entered the shower thinking Marge was in it. Really it was Selma and he was disgusted so he poured bleach in his eyes. Then Bart was a about to enter so he poured bleach in his eyes too. Bart then thanks Homer.
#
#
# Homer seems Bart making a mess and gets angry. He says he's going to punish him seriously this time. Then the ice cream truck comes and he gets distracted. Then they both each ice cream together instead.
#
#
# [['silly', 'fatherly', 'sweet', 'considerate', 'crazy'], ['0', '1', '0', '-1', '1']]
#
#
# [['silly', 'expected', 'mischievous', 'punishment', 'son'], ['1', '0', '1', '0', '0']]
#
#
# ['family care']
#
#
# ['family care']
#
#
# ALFHWKHPH59LX
# 39N5ACM9HFZGMAWTF3WE3CAI4DZ9PL
# 1.0
#
#
# Games of Thrones is a fictional series. In this play it means victory or death. This epic may have all the traps of a strange, violent fantasy world where the real plot of the series really is. A series that tells the story of a civil war in a medieval country.
#
#
# The nine noble families wage war against each other. Bloodshed across the seven kingdoms. the battle of thrones come to an end. Finally the the kingdom'st truth will revealed.
#
#
# [['Victory', 'Violent', 'War', 'Empathy', 'power'], ['2', '1', '2', '1', '2']]
#
#
# [['Battle', 'Truth', 'Revealed', 'dragon', 'against'], ['2', '1', '2', '1', '2']]
#
#
# ['other']
#
#
# ['other']
#
#
# A3QUWIT972BYUH
# 3FE2ERCCZYKJTX0ZHSFW0257Z69OPQ
# 1.0
#
#
# I remember when Walt got diagnosed with lung cancer.  Before that he was a law abiding teacher.  He felt desperate to leave money for his family.  It was the pivotal point in the show and many could relate to the decisions he made at that point.
#
#
# I remember when Walt let Jess's girlfriend die by choking on her throw up due to an overdose.  He wanted Jesse to stay with him.  It exemplified how far gone his moral compass was.  I was very haunted by this moment.
#
#
# [['sad', 'upsetting', 'empathy', 'fear', 'caring'], ['2', '2', '2', '2', '2']]
#
#
# [['ruthless', 'shocking', 'disgust', 'unredeemable', 'sad'], ['2', '2', '2', '2', '2']]
#
#
# ['work', 'family care']
#
#
# ['other']
#
#
# A3OB4WYRTLMT0Z
# 35GCEFQ6I60OLC9JL3T63X9AEBCZ3D
# 1.0
#
#
# I remember Leslie's reaction to Joe Biden. She loved him! On one episode when the cast was visiting D.C., the V.P. appeared on the show, and she got to meet her political idol. Ben had arranged the meeting as an engagement present. Leslie stammered and laughed like a star-struck girl. She was thrilled, grabbed his hands and wouldn't let go and called him handsome.
#
#
# I remember when Chris Pratt showed up naked after Leslie wanted to meet to talk. He'd been living outside in some trashy area after breaking up with Ann. Ann said he'd shown up naked on other occasions. Leslie was horrified. Ann left out of annoyance.
#
#
# [['Funny', 'Surprising', 'Thrilling', 'Memorable', 'Cute'], ['2', '2', '2', '0', '1']]
#
#
# [['Silly', 'Funny', 'Surprising', 'Goofy', 'Endearing'], ['2', '2', '2', '2', '1']]
#
#
# ['socializing', 'community/civic/religious']
#
#
# ['socializing', 'community/civic/religious']
#
#
# ACX6PW2PNRT2C
# 37C0GNLMHGFKFUR5CN27J82R0K4D6Y
# 1.0
#
#
# I remember when the old man in the wheelchair had a bomb that would go off when he rang his bell. And Gus went to see the old man. When the bomb went off, Gus walked out of the door. Half of Gus's face had been blown off.
#
#
# Jesse and his girlfriend were high in his house. They had taken too much heroin. Walter came in and saw them in bad shape. The girlfriend started to get sick. Walter left her to die.
#
#
# [['gory', 'shocking', 'gruesome'], ['1', '2', '2']]
#
#
# [['sad', 'surprising'], ['2', '1']]
#
#
# ['other']
#
#
# ['other']
#
#
# A2949EJ4EVG6LM
# 3LEP4MGT3HCQL6808EJFUOOJEOOBDW
# 1.0
#
#
# game of thrones is the best show . unlike most of the other stories which have one main character and a few other side characters, game of thrones has many characters most of whom are simply awesome. from the scheming little finger to the secretive and creepily intimidating varys , from the honorable starks to the disgusting lannisters, freys and boltons, from the gigantic mountain and the hound to the minuscule. yet vastly brilliant tyrion , from dragons to the white walkers there is simply no dearth of interesting characters.
#
#
# the beheading of ned stark at the end of season 1 . robb is fighting for his sisters and to avenge his fathers death. when the dragons were introduced in the series, i got goosebumps. everyone is a shade of grey.
#
#
# [['nostalgic', 'favorites', 'cherish', 'descriptive', 'thougtful'], ['2', '1', '1', '1', '1']]
#
#
# [['surprise', 'nostalgic', 'engaging', 'revenge', 'war'], ['2', '1', '0', '2', '2']]
#
#
# ['other']
#
#
# ['other']
#
#
# A20VNT5IHVO401
# 39OWYR0EPL3JWYF79CSPQZP5B7DFYB
# 1.0
#
#
# when the female lead was undercover at a prison and a guard assaulted her.  She was very traumatized by this and it carried over into the following episodes.  She acted the character perfectly.
#
#
# when the mother of the child she was taking care of came back and she was worried about losing the baby.  I believe the woman ended up dying . It was very heartbreaking.
#
#
# [['hurtful', 'painful', 'terror', 'hopeless', 'powerless'], ['1', '1', '1', '0', '2']]
#
#
# [['love', 'hope', 'loss', 'pain', 'sorrow'], ['1', '2', '2', '1', '2']]
#
#
# ['other']
#
#
# ['family care']
#
#
# AQN4Q1SYLSHML
# 3TAYZSBPLMK2ZIRMMBLTOU7FLSZS2X
# 0.7777777777777778
#
#
# I can recall all the episodes in the game of thrones it s a family wage war against each other to control land . its a true story  its a epic might brave all trappings violent fantasy world  the actual plot of series is based in reality westerns is essentially a mirrored version of  England & Scotland
#
#
# ' The Iron Throne " ,Bran stark  inarguably the least useful character who managed to survive all eight seasons 0f game of the thrones  After much turmoil and bloodshed across seven kingdoms the battle came to end
#
#
# [['throne', 'control land', 'war', 'family wage', 'true story'], ['1', '2', '1', '2', '2']]
#
#
# [['bran stark', 'bloodshed', 'seven kingdom', 'iron throne', 'family jealous'], ['1', '2', '1', '1', '2']]
#
#
# ['personal or home leisure', 'socializing', 'pets']
#
#
# ['personal or home leisure', 'pets']
#
#
# A2QPMJ4GADLUW2
# 30LSNF239V7D54OQHZRFKS1SCVFI2F
# 1.0
#
#
# Ned Stark was condemned to execution by King Joffrey. Ned was going to reveal that Cersei and Jamie Lannister were incestuous lovers. The children who were thought to be fathered by the former king were products of this brother/sister relationship. Ned Stark was beheaded by the Lannisters to prevent this knowledge from becoming known.
#
#
# The White Walkers pass through the wall and attack Winterfell. The Night King, an undead person, resureccts a fallen dragon and uses it to melt a giant ice wall. The wall had been keeping them out of Westeros and away from humans. A large battle ensues and the Walkers look like they will win. However, Arya Stark is able to kill the Night King, which causes the entirety of the White Walkers to perish.
#
#
# [['Death', 'Betrayal', 'Secrets', 'Disclosure', 'Scheme'], ['1', '2', '2', '1', '1']]
#
#
# [['Undead', 'War', 'Swords', 'Dragons', 'Winterfell'], ['2', '2', '0', '1', '1']]
#
#
# ['other']
#
#
# ['other']
#
#
# A157MPD27GOA1U
# 3WT783CTPCTGGE2M8IO4AI61TWIBCI
# 1.0
#
#
# I remember the part in Breaking Bad where Jessie and Jane were passed out on the bed after doing drugs. Walter White walks in the room to get Jessie cause he knows he was drugged out. Jane happens to start convulsing and vomiting while sleeping, which means she was overdosing. Instead of Walter helping Jane and turning her on her side he let her aspirate her vomit and it led to her dying. Walter watched the whole thing happen and once she died he left without even waking Jessie up.
#
#
# I remember the part where the guy in the wheelchair with the bell was ringing the bell when Gustavo was in his hospital room. The scene was that it blew up and the guy in the wheelchair was almost like a suicide bomber. He rang the bell enough times and the room blew up, then you see Gus emerge from the violent scene rearranging his tie. The scene cuts to him turning his head and half Gus' face was gone! Then he falls to the floor.
#
#
# [['sad', 'horrifying', 'repulsive', 'angry', 'intentional'], ['2', '2', '2', '2', '2']]
#
#
# [['grotesque', 'cool', 'grizzly', 'nasty', 'bloody'], ['2', '-1', '2', '2', '2']]
#
#
# ['sleep']
#
#
# ['other']
#
#
# A7D8ZNKH2E12F
# 37QW5D2ZRHYDLXTB2SUUYLKI7LK8SV
# 1.0
#
#
# Game ofThrones is an HBO series that tells the story of a medieval country civil war.my favourite dialogue in game of thrones is, as queen cersei says in season one 'when you play the game of thrones you win or die'. there is no middle ground.
#
#
# Jon Arryn, the king's Hand, dies unexpectedly in kings landing, the capital of the seven kingdoms. Ned's old friend king Robert parathion visits winter fall to recruit him and propose a marriage between his heir joffrey and Ned's daughter sansa.
#
#
# [['queen', 'game ', 'win', 'die', 'middle ground'], ['2', '2', '2', '2', '1']]
#
#
# [['king', 'unexpected', 'marriage', 'joyful', 'sad'], ['2', '2', '1', '1', '1']]
#
#
# ['other']
#
#
# ['other']
